# %%
# Primeiramente, começamos importando as bibliotecas que iremos usar no
# restante do projeto
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report

import nltk
from nltk.corpus import stopwords

# %%
# Fazemos o download das stopwords (palavras comuns em determinada língua)
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Carregamos o csv com os dados
df = pd.read_csv('https://raw.githubusercontent.com/Dssdiego/sad_prova1/master/dados.csv')
df.head()
# Out:
#                                             mensagem classificacao
# 0  Nordeste poderia sair do mapa do Brasil... mor...          hate
# 1  Essa corrente negativa de pessoas desejando a ...       regular
# 2  Não maltrataram ela? Não a estruparam com viol...          hate
# 3  Encerrando o dia com o posicionamento da XboxB...       regular
# 4  Quero ir num aeroporto brasileiro só pra ver p...          hate

# %%
# Verificamos que os dados estão igualmente distribuídos
# (para não criar tendência na classificação)
df['classificacao'].value_counts()
# Out:
# regular    14
# hate       14
# Name: classificacao, dtype: int64

# %%
# Definimos os eixos X e Y
X = df['mensagem']
y = df['classificacao']

# %%
# Separamos os dados em conjuntos de *treino* e *teste* 
# (80% treino / 20% teste)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Verificamos os dados de treino e teste em uma tabela
pd.DataFrame({'mensagem': X_train, 'classificacao': y_train})
# Out:
#                                              mensagem classificacao
# 24  eu não tenho raiva, nem ódio, muito menos desp...          hate
# 13       Nem queria namorar com você, queria casar só       regular
# 20  Quem apoio Trum e Bolsonaro, é retardado... Fa...          hate
# 25  quando eu falo que quem me trouxe pro kpop foi...       regular
# 16  Deveria acontecer o que aconteceu na Argentina...          hate
# 1   Essa corrente negativa de pessoas desejando a ...       regular
# 10  O povo precisa providenciar o enforcamento de ...          hate
# 27  alias falano em gif eu imprimi um esses dia. n...       regular
# 26  A racismo começa apartir de que nuvens pretas ...          hate
# 8   o brasileiro esperando mais de 7 mes pra vacin...          hate
# 6   Não vejo a hora do Lula morrer. Não é discurso...          hate
# 4   Quero ir num aeroporto brasileiro só pra ver p...          hate
# 18  os brasileiros sao tudo nogento, ainda bem que...          hate
# 19  Nem todos sabem o q passei pra chegar até aqui...       regular
# 9   Discurso de ódio não é liberdade de expressão....       regular
# 7          Hoje eu finalmente entendi o que é um meme       regular
# 23  alguem sabe um lugar aqui em santos que vai te...       regular
# 3   Encerrando o dia com o posicionamento da XboxB...       regular
# 0   Nordeste poderia sair do mapa do Brasil... mor...          hate
# 21  Queria um Google na cabeça e umm anti-virus no...       regular
# 15  O GERENTE FICOU MALUCO tudo pela metade do pre...       regular
# 12  Então estou ansioso esperando alguém dar um ti...          hate

# %%
# Como máquinas não entendem textos, calculamos a frequência de palavras de cada 
# mensagem em uma medida chamada tf-idf (Term Frequency, Inverse Document 
# Frequency), que é uma medida estatística que tem o intuito de indicar a 
# importância de uma palavra de um documento em relação a uma coleção de 
# documentos em um corpus linguístico.

# Para a criação dessa medida, usamos alguns classificadores:

# "encoding" é UTF-8 para garantir o uso de acentos existentes na língua portuguesa
# "ngram_range" é (1,3) para indicar que consideraremos conjuntos de 1 a 3 palavras
# "stop_words" é "portuguese" para remover "palavras comuns" da língua portuguesa

tfidf = TfidfVectorizer(encoding='utf-8', ngram_range=(1,3), 
                                       stop_words=stopwords.words('portuguese'))

# %%
# Em seguida, criamos uma pipeline que "junta" a medida tf-idf com o modelo de 
# classificação Naive Bayes Multinomial
modelo = make_pipeline(tfidf, MultinomialNB())

# %%
# Realizamos o treinamento do modelo
modelo.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidfvectorizer',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 3), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=['de', 'a', 'o', 'que', 'e', 'é',
#                                              'do', 'da', 'em', 'um', 'para',
#                                              'com', 'não', 'uma', 'os', 'no',
#                                              'se', 'na', 'por', 'mais', 'as',
#                                              'dos', 'como', 'mas', 'ao', 'ele',
#                                              'das', 'à', 'seu', 'sua', ...],
#                                  strip_accents=None, sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('multinomialnb',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
# Confirmamos quais as saídas do modelo
print(modelo.classes_)
# Out:
# ['hate' 'regular']

# %%
# Verificamos o vocabulário criado pela medida Tfidf e seus respectivos pesos
tfidf.vocabulary_
# Out:
# {'12h': 0,
#  '12h pq': 1,
#  '12h pq tá': 2,
#  'acontecer': 3,
#  'acontecer aconteceu': 4,
#  'acontecer aconteceu argentina': 5,
#  'aconteceu': 6,
#  'aconteceu argentina': 7,
#  'aconteceu argentina onde': 8,
#  'acordar': 9,
#  'acordar males': 10,
#  'acordar males sofreu': 11,
#  'aeroporto': 12,
#  'aeroporto brasileiro': 13,
#  'aeroporto brasileiro pra': 14,
#  'agora': 15,
#  'agora fazer': 16,
#  'agora fazer choro': 17,
#  'agora ficou': 18,
#  'agora ficou impasse': 19,
#  'agora né': 20,
#  'agora né sonho': 21,
#  'ahhaha': 22,
#  'ainda': 23,
#  'ainda bem': 24,
#  'ainda bem moro': 25,
#  'ajuda': 26,
#  'ajuda volta': 27,
#  'ajuda volta pra': 28,
#  'alegria': 29,
#  'alegria superação': 30,
#  'alegria superação garra': 31,
#  'alguem': 32,
#  'alguem sabe': 33,
#  'alguem sabe lugar': 34,
#  'algum': 35,
#  'algum lugar': 36,
#  'algum lugar mundo': 37,
#  'alguém': 38,
#  'alguém dar': 39,
#  'alguém dar tiro': 40,
#  'alguém sabe': 41,
#  'alguém sabe responder': 42,
#  'alias': 43,
#  'alias falano': 44,
#  'alias falano gif': 45,
#  'anda': 46,
#  'anda avião': 47,
#  'ansioso': 48,
#  'ansioso esperando': 49,
#  'ansioso esperando alguém': 50,
#  'anti': 51,
#  'anti virus': 52,
#  'anti virus coreação': 53,
#  'apartir': 54,
#  'apartir nuvens': 55,
#  'apartir nuvens pretas': 56,
#  'apenas': 57,
#  'apenas consigo': 58,
#  'apenas consigo imaginar': 59,
#  'apoio': 60,
#  'apoio equipe': 61,
#  'apoio equipe xbox': 62,
#  'apoio trum': 63,
#  'apoio trum bolsonaro': 64,
#  'aqui': 65,
#  'aqui falar': 66,
#  'aqui falar papagaio': 67,
#  'aqui santos': 68,
#  'aqui santos vai': 69,
#  'argentina': 70,
#  'argentina onde': 71,
#  'argentina onde jogaram': 72,
#  'atirou': 73,
#  'atirou presidente': 74,
#  'atirou presidente kennedy': 75,
#  'avião': 76,
#  'aí': 77,
#  'aí vai': 78,
#  'aí vai td': 79,
#  'bandido': 80,
#  'bandido vai': 81,
#  'bandido vai ver': 82,
#  'bando': 83,
#  'bando vermes': 84,
#  'bando vermes raiva': 85,
#  'barrado': 86,
#  'barrado entrada': 87,
#  'barrado entrada pois': 88,
#  'bem': 89,
#  'bem moro': 90,
#  'bem moro minas': 91,
#  'bolsa': 92,
#  'bolsa caralho': 93,
#  'bolsa caralho bando': 94,
#  'bolsonaro': 95,
#  'bolsonaro diz': 96,
#  'bolsonaro diz nao': 97,
#  'bolsonaro forte': 98,
#  'bolsonaro forte orações': 99,
#  'bolsonaro retardado': 100,
#  'bolsonaro retardado falou': 101,
#  'bons': 102,
#  'bons ensolarados': 103,
#  'brancas': 104,
#  'brancas dias': 105,
#  'brancas dias bons': 106,
#  'brasil': 107,
#  'brasil melhor': 108,
#  'brasil melhor vamos': 109,
#  'brasil morram': 110,
#  'brasil morram fome': 111,
#  'brasileiro': 112,
#  'brasileiro esperando': 113,
#  'brasileiro esperando mes': 114,
#  'brasileiro pra': 115,
#  'brasileiro pra ver': 116,
#  'brasileiros': 117,
#  'brasileiros sao': 118,
#  'brasileiros sao tudo': 119,
#  'bts': 120,
#  'bts pessoas': 121,
#  'bts pessoas ficam': 122,
#  'cabeça': 123,
#  'cabeça bolsonaro': 124,
#  'cabeça umm': 125,
#  'cabeça umm anti': 126,
#  'cara': 127,
#  'cara atirou': 128,
#  'cara atirou presidente': 129,
#  'caralho': 130,
#  'caralho bando': 131,
#  'caralho bando vermes': 132,
#  'caralho vamo': 133,
#  'caralho vamo chama': 134,
#  'casar': 135,
#  'certamente': 136,
#  'certamente impresora': 137,
#  'certamente impresora defeito': 138,
#  'chama': 139,
#  'chama cara': 140,
#  'chama cara atirou': 141,
#  'chegar': 142,
#  'chegar aqui': 143,
#  'chegar aqui falar': 144,
#  'china': 145,
#  'china serio': 146,
#  'china serio facada': 147,
#  'chocadas': 148,
#  'chocadas ahhaha': 149,
#  'choro': 150,
#  'choro alegria': 151,
#  'choro alegria superação': 152,
#  'chuvosos': 153,
#  'chuvosos nuvens': 154,
#  'chuvosos nuvens brancas': 155,
#  'clientes': 156,
#  'clientes tb': 157,
#  'clientes tb ficaram': 158,
#  'coisas': 159,
#  'coisas nunca': 160,
#  'coisas nunca fáceis': 161,
#  'começa': 162,
#  'começa apartir': 163,
#  'começa apartir nuvens': 164,
#  'compra': 165,
#  'compra porque': 166,
#  'compra porque eh': 167,
#  'compromisso': 168,
#  'compromisso valores': 169,
#  'compromisso valores fundamentais': 170,
#  'consigo': 171,
#  'consigo imaginar': 172,
#  'consigo imaginar travesti': 173,
#  'continua': 174,
#  'continua sonho': 175,
#  'continua sonho objetivo': 176,
#  'coreação': 177,
#  'coreação rsrsrsrsrssrsrrsrsrsrs': 178,
#  'coronavirus': 179,
#  'coronavirus bolsonaro': 180,
#  'coronavirus bolsonaro diz': 181,
#  'corrente': 182,
#  'corrente negativa': 183,
#  'corrente negativa pessoas': 184,
#  'crime': 185,
#  'dada': 186,
#  'dada caralho': 187,
#  'dada caralho vamo': 188,
#  'dar': 189,
#  'dar tiro': 190,
#  'dar tiro cabeça': 191,
#  'defeito': 192,
#  'deixa': 193,
#  'deixa saudades': 194,
#  'deixa saudades exemplo': 195,
#  'desejando': 196,
#  'desejando morte': 197,
#  'desejando morte bolsonaro': 198,
#  'desprezo': 199,
#  'desprezo travestis': 200,
#  'desprezo travestis apenas': 201,
#  'dessa': 202,
#  'dessa gente': 203,
#  'dessa gente aí': 204,
#  'desse': 205,
#  'desse sujeito': 206,
#  'desse sujeito deixa': 207,
#  'deveria': 208,
#  'deveria acontecer': 209,
#  'deveria acontecer aconteceu': 210,
#  'dia': 211,
#  'dia nao': 212,
#  'dia nao ta': 213,
#  'dia posicionamento': 214,
#  'dia posicionamento xboxbr': 215,
#  'dias': 216,
#  'dias bons': 217,
#  'dias bons ensolarados': 218,
#  'dias ruins': 219,
#  'dias ruins chuvosos': 220,
#  'discurso': 221,
#  'discurso ódio': 222,
#  'discurso ódio liberdade': 223,
#  'discurso ódio sim': 224,
#  'discursos': 225,
#  'discursos ódio': 226,
#  'discursos ódio preconceituosos': 227,
#  'diversidade': 228,
#  'diversidade inclusão': 229,
#  'diversidade inclusão discursos': 230,
#  'diz': 231,
#  'diz nao': 232,
#  'diz nao vai': 233,
#  'dobro': 234,
#  'dobro agora': 235,
#  'dobro agora ficou': 236,
#  'dormindo': 237,
#  'eh': 238,
#  'eh china': 239,
#  'eh china serio': 240,
#  'encerrando': 241,
#  'encerrando dia': 242,
#  'encerrando dia posicionamento': 243,
#  'enforcamento': 244,
#  'enforcamento sérgio': 245,
#  'enforcamento sérgio moro': 246,
#  'ensolarados': 247,
#  'entendi': 248,
#  'entendi meme': 249,
#  'entrada': 250,
#  'entrada pois': 251,
#  'entrada pois temer': 252,
#  'então': 253,
#  'então ansioso': 254,
#  'então ansioso esperando': 255,
#  'equipe': 256,
#  'equipe xbox': 257,
#  'equipe xbox seguidores': 258,
#  'escravos': 259,
#  'escravos mar': 260,
#  'escravos mar alguém': 261,
#  'esperando': 262,
#  'esperando alguém': 263,
#  'esperando alguém dar': 264,
#  'esperando mes': 265,
#  'esperando mes pra': 266,
#  'espere': 267,
#  'espere clientes': 268,
#  'espere clientes tb': 269,
#  'exemplo': 270,
#  'exemplo nação': 271,
#  'exemplo nação acordar': 272,
#  'existe': 273,
#  'existe algum': 274,
#  'existe algum lugar': 275,
#  'expressão': 276,
#  'expressão crime': 277,
#  'facada': 278,
#  'facada mal': 279,
#  'facada mal dada': 280,
#  'fala': 281,
#  'fala agora': 282,
#  'fala agora fazer': 283,
#  'falano': 284,
#  'falano gif': 285,
#  'falano gif imprimi': 286,
#  'falar': 287,
#  'falar papagaio': 288,
#  'falar papagaio fala': 289,
#  'falo': 290,
#  'falo trouxe': 291,
#  'falo trouxe pro': 292,
#  'falou': 293,
#  'falou feminazi': 294,
#  'falou feminazi maconheiro': 295,
#  'falso': 296,
#  'falso juiz': 297,
#  'falso juiz praça': 298,
#  'fazer': 299,
#  'fazer choro': 300,
#  'fazer choro alegria': 301,
#  'feminazi': 302,
#  'feminazi maconheiro': 303,
#  'feminazi maconheiro bandido': 304,
#  'ficam': 305,
#  'ficam chocadas': 306,
#  'ficam chocadas ahhaha': 307,
#  'ficaram': 308,
#  'ficaram malucos': 309,
#  'ficaram malucos querem': 310,
#  'ficou': 311,
#  'ficou impasse': 312,
#  'ficou maluco': 313,
#  'ficou maluco tudo': 314,
#  'finalmente': 315,
#  'finalmente entendi': 316,
#  'finalmente entendi meme': 317,
#  'foda': 318,
#  'fome': 319,
#  'fome vivam': 320,
#  'fome vivam bolsa': 321,
#  'forte': 322,
#  'forte orações': 323,
#  'forte orações milhões': 324,
#  'fudido': 325,
#  'fudido ódio': 326,
#  'fudido ódio ódio': 327,
#  'fundamentais': 328,
#  'fundamentais respeito': 329,
#  'fundamentais respeito diversidade': 330,
#  'fáceis': 331,
#  'fáceis agora': 332,
#  'fáceis agora né': 333,
#  'garra': 334,
#  'garra vida': 335,
#  'garra vida coisas': 336,
#  'gente': 337,
#  'gente aí': 338,
#  'gente aí vai': 339,
#  'gerais': 340,
#  'gerente': 341,
#  'gerente ficou': 342,
#  'gerente ficou maluco': 343,
#  'gif': 344,
#  'gif imprimi': 345,
#  'gif imprimi dia': 346,
#  'google': 347,
#  'google cabeça': 348,
#  'google cabeça umm': 349,
#  'histório': 350,
#  'histório desse': 351,
#  'histório desse sujeito': 352,
#  'hoje': 353,
#  'hoje finalmente': 354,
#  'hoje finalmente entendi': 355,
#  'hora': 356,
#  'hora lula': 357,
#  'hora lula morrer': 358,
#  'imaginar': 359,
#  'imaginar travesti': 360,
#  'imaginar travesti pelado': 361,
#  'impasse': 362,
#  'impresora': 363,
#  'impresora defeito': 364,
#  'imprimi': 365,
#  'imprimi dia': 366,
#  'imprimi dia nao': 367,
#  'inclusão': 368,
#  'inclusão discursos': 369,
#  'inclusão discursos ódio': 370,
#  'ir': 371,
#  'ir aeroporto': 372,
#  'ir aeroporto brasileiro': 373,
#  'jogaram': 374,
#  'jogaram todos': 375,
#  'jogaram todos escravos': 376,
#  'jogo': 377,
#  'juiz': 378,
#  'juiz praça': 379,
#  'juiz praça pública': 380,
#  'juntas': 381,
#  'juntas presidente': 382,
#  'juntas presidente luta': 383,
#  'kard': 384,
#  'kard bts': 385,
#  'kard bts pessoas': 386,
#  'kennedy': 387,
#  'kpop': 388,
#  'kpop kard': 389,
#  'kpop kard bts': 390,
#  'liberdade': 391,
#  'liberdade expressão': 392,
#  'liberdade expressão crime': 393,
#  'lugar': 394,
#  'lugar aqui': 395,
#  'lugar aqui santos': 396,
#  'lugar mundo': 397,
#  'lugar mundo onde': 398,
#  'lula': 399,
#  'lula morrer': 400,
#  'lula morrer discurso': 401,
#  'luta': 402,
#  'luta brasil': 403,
#  'luta brasil melhor': 404,
#  'maconheiro': 405,
#  'maconheiro bandido': 406,
#  'maconheiro bandido vai': 407,
#  'mal': 408,
#  'mal dada': 409,
#  'mal dada caralho': 410,
#  'males': 411,
#  'males sofreu': 412,
#  'maluco': 413,
#  'maluco tudo': 414,
#  'maluco tudo metade': 415,
#  'malucos': 416,
#  'malucos querem': 417,
#  'malucos querem pagar': 418,
#  'mapa': 419,
#  'mapa brasil': 420,
#  'mapa brasil morram': 421,
#  'mar': 422,
#  'mar alguém': 423,
#  'mar alguém sabe': 424,
#  'melhor': 425,
#  'melhor vamos': 426,
#  'melhor vamos vencer': 427,
#  'meme': 428,
#  'menos': 429,
#  'menos desprezo': 430,
#  'menos desprezo travestis': 431,
#  'merece': 432,
#  'mes': 433,
#  'mes pra': 434,
#  'mes pra vacina': 435,
#  'metade': 436,
#  'metade preço': 437,
#  'metade preço espere': 438,
#  'mexendo': 439,
#  'mexendo certamente': 440,
#  'mexendo certamente impresora': 441,
#  'milhões': 442,
#  'milhões pessoas': 443,
#  'milhões pessoas juntas': 444,
#  'minas': 445,
#  'minas gerais': 446,
#  'moro': 447,
#  'moro falso': 448,
#  'moro falso juiz': 449,
#  'moro minas': 450,
#  'moro minas gerais': 451,
#  'morram': 452,
#  'morram fome': 453,
#  'morram fome vivam': 454,
#  'morrer': 455,
#  'morrer discurso': 456,
#  'morrer discurso ódio': 457,
#  'morte': 458,
#  'morte bolsonaro': 459,
#  'morte bolsonaro forte': 460,
#  'mundo': 461,
#  'mundo onde': 462,
#  'mundo onde negros': 463,
#  'namorar': 464,
#  'namorar queria': 465,
#  'namorar queria casar': 466,
#  'nao': 467,
#  'nao ta': 468,
#  'nao ta mexendo': 469,
#  'nao vai': 470,
#  'nao vai compra': 471,
#  'nação': 472,
#  'nação acordar': 473,
#  'nação acordar males': 474,
#  'negativa': 475,
#  'negativa pessoas': 476,
#  'negativa pessoas desejando': 477,
#  'negros': 478,
#  'negros prosperidade': 479,
#  'nogento': 480,
#  'nogento ainda': 481,
#  'nogento ainda bem': 482,
#  'nojo': 483,
#  'nojo sério': 484,
#  'nordeste': 485,
#  'nordeste poderia': 486,
#  'nordeste poderia sair': 487,
#  'nunca': 488,
#  'nunca fáceis': 489,
#  'nunca fáceis agora': 490,
#  'nuvens': 491,
#  'nuvens brancas': 492,
#  'nuvens brancas dias': 493,
#  'nuvens pretas': 494,
#  'nuvens pretas dias': 495,
#  'né': 496,
#  'né sonho': 497,
#  'né sonho continua': 498,
#  'objetivo': 499,
#  'objetivo parabéns': 500,
#  'objetivo parabéns partida': 501,
#  'obrigado': 502,
#  'obrigado apoio': 503,
#  'obrigado apoio equipe': 504,
#  'onde': 505,
#  'onde jogaram': 506,
#  'onde jogaram todos': 507,
#  'onde negros': 508,
#  'onde negros prosperidade': 509,
#  'orações': 510,
#  'orações milhões': 511,
#  'orações milhões pessoas': 512,
#  'pagar': 513,
#  'pagar dobro': 514,
#  'pagar dobro agora': 515,
#  'pagodinho': 516,
#  'pagodinho jogo': 517,
#  'papagaio': 518,
#  'papagaio fala': 519,
#  'papagaio fala agora': 520,
#  'parabéns': 521,
#  'parabéns partida': 522,
#  'parabéns partida rapaziada': 523,
#  'partida': 524,
#  'partida rapaziada': 525,
#  'partida rapaziada vcs': 526,
#  'passarão': 527,
#  'passarão obrigado': 528,
#  'passarão obrigado apoio': 529,
#  'passei': 530,
#  'passei pra': 531,
#  'passei pra chegar': 532,
#  'paz': 533,
#  'paz histório': 534,
#  'paz histório desse': 535,
#  'pedir': 536,
#  'pedir ajuda': 537,
#  'pedir ajuda volta': 538,
#  'pelado': 539,
#  'pelado nojo': 540,
#  'pelado nojo sério': 541,
#  'pessoas': 542,
#  'pessoas desejando': 543,
#  'pessoas desejando morte': 544,
#  'pessoas ficam': 545,
#  'pessoas ficam chocadas': 546,
#  'pessoas juntas': 547,
#  'pessoas juntas presidente': 548,
#  'pobre': 549,
#  'pobre anda': 550,
#  'pobre anda avião': 551,
#  'pobre sendo': 552,
#  'pobre sendo barrado': 553,
#  'poderia': 554,
#  'poderia sair': 555,
#  'poderia sair mapa': 556,
#  'pois': 557,
#  'pois temer': 558,
#  'pois temer pobre': 559,
#  'porque': 560,
#  'porque eh': 561,
#  'porque eh china': 562,
#  'posicionamento': 563,
#  'posicionamento xboxbr': 564,
#  'posicionamento xboxbr reafirmando': 565,
#  'povo': 566,
#  'povo precisa': 567,
#  'povo precisa providenciar': 568,
#  'pq': 569,
#  'pq tá': 570,
#  'pq tá dormindo': 571,
#  'pqp': 572,
#  'pqp sim': 573,
#  'pqp sim td': 574,
#  'pra': 575,
#  'pra chegar': 576,
#  'pra chegar aqui': 577,
#  'pra pqp': 578,
#  'pra pqp sim': 579,
#  'pra terra': 580,
#  'pra terra volta': 581,
#  'pra vacina': 582,
#  'pra vacina coronavirus': 583,
#  'pra ver': 584,
#  'pra ver pobre': 585,
#  'praça': 586,
#  'praça pública': 587,
#  'praça pública traidor': 588,
#  'precisa': 589,
#  'precisa providenciar': 590,
#  'precisa providenciar enforcamento': 591,
#  'preconceituosos': 592,
#  'preconceituosos passarão': 593,
#  'preconceituosos passarão obrigado': 594,
#  'presidente': 595,
#  'presidente kennedy': 596,
#  'presidente luta': 597,
#  'presidente luta brasil': 598,
#  'pretas': 599,
#  'pretas dias': 600,
#  'pretas dias ruins': 601,
#  'preço': 602,
#  'preço espere': 603,
#  'preço espere clientes': 604,
#  'pro': 605,
#  'pro kpop': 606,
#  'pro kpop kard': 607,
#  'prosperidade': 608,
#  'providenciar': 609,
#  'providenciar enforcamento': 610,
#  'providenciar enforcamento sérgio': 611,
#  'pátria': 612,
#  'pátria merece': 613,
#  'pública': 614,
#  'pública traidor': 615,
#  'pública traidor pátria': 616,
#  'querem': 617,
#  'querem pagar': 618,
#  'querem pagar dobro': 619,
#  'queria': 620,
#  'queria casar': 621,
#  'queria google': 622,
#  'queria google cabeça': 623,
#  'queria namorar': 624,
#  'queria namorar queria': 625,
#  'quero': 626,
#  'quero ir': 627,
#  'quero ir aeroporto': 628,
#  'racismo': 629,
#  'racismo começa': 630,
#  'racismo começa apartir': 631,
#  'raiva': 632,
#  'raiva ódio': 633,
#  'raiva ódio dessa': 634,
#  'raiva ódio menos': 635,
#  'rapaziada': 636,
#  'rapaziada vcs': 637,
#  'rapaziada vcs foda': 638,
#  'reafirmando': 639,
#  'reafirmando compromisso': 640,
#  'reafirmando compromisso valores': 641,
#  'respeito': 642,
#  'respeito diversidade': 643,
#  'respeito diversidade inclusão': 644,
#  'responder': 645,
#  'responder existe': 646,
#  'responder existe algum': 647,
#  'retardado': 648,
#  'retardado falou': 649,
#  'retardado falou feminazi': 650,
#  'rsrsrsrsrssrsrrsrsrsrs': 651,
#  'ruins': 652,
#  'ruins chuvosos': 653,
#  'ruins chuvosos nuvens': 654,
#  'sabe': 655,
#  'sabe lugar': 656,
#  'sabe lugar aqui': 657,
#  'sabe responder': 658,
#  'sabe responder existe': 659,
#  'sabem': 660,
#  'sabem passei': 661,
#  'sabem passei pra': 662,
#  'sair': 663,
#  'sair mapa': 664,
#  'sair mapa brasil': 665,
#  'santos': 666,
#  'santos vai': 667,
#  'santos vai ter': 668,
#  'sao': 669,
#  'sao tudo': 670,
#  'sao tudo nogento': 671,
#  'saudades': 672,
#  'saudades exemplo': 673,
#  'saudades exemplo nação': 674,
#  'seguidores': 675,
#  'sendo': 676,
#  'sendo barrado': 677,
#  'sendo barrado entrada': 678,
#  'serio': 679,
#  'serio facada': 680,
#  'serio facada mal': 681,
#  'sim': 682,
#  'sim paz': 683,
#  'sim paz histório': 684,
#  'sim td': 685,
#  'sim td fudido': 686,
#  'sofreu': 687,
#  'sonho': 688,
#  'sonho continua': 689,
#  'sonho continua sonho': 690,
#  'sonho objetivo': 691,
#  'sonho objetivo parabéns': 692,
#  'sujeito': 693,
#  'sujeito deixa': 694,
#  'sujeito deixa saudades': 695,
#  'superação': 696,
#  'superação garra': 697,
#  'superação garra vida': 698,
#  'sérgio': 699,
#  'sérgio moro': 700,
#  'sérgio moro falso': 701,
#  'sério': 702,
#  'ta': 703,
#  'ta mexendo': 704,
#  'ta mexendo certamente': 705,
#  'tag': 706,
#  'tag 12h': 707,
#  'tag 12h pq': 708,
#  'tb': 709,
#  'tb ficaram': 710,
#  'tb ficaram malucos': 711,
#  'td': 712,
#  'td fudido': 713,
#  'td fudido ódio': 714,
#  'td tv': 715,
#  'td tv pedir': 716,
#  'temer': 717,
#  'temer pobre': 718,
#  'temer pobre anda': 719,
#  'ter': 720,
#  'ter pagodinho': 721,
#  'ter pagodinho jogo': 722,
#  'terra': 723,
#  'terra volta': 724,
#  'terra volta pra': 725,
#  'tiro': 726,
#  'tiro cabeça': 727,
#  'tiro cabeça bolsonaro': 728,
#  'todos': 729,
#  'todos escravos': 730,
#  'todos escravos mar': 731,
#  'todos sabem': 732,
#  'todos sabem passei': 733,
#  'traidor': 734,
#  'traidor pátria': 735,
#  'traidor pátria merece': 736,
#  'travesti': 737,
#  'travesti pelado': 738,
#  'travesti pelado nojo': 739,
#  'travestis': 740,
#  'travestis apenas': 741,
#  'travestis apenas consigo': 742,
#  'trouxe': 743,
#  'trouxe pro': 744,
#  'trouxe pro kpop': 745,
#  'trum': 746,
#  'trum bolsonaro': 747,
#  'trum bolsonaro retardado': 748,
#  'tudo': 749,
#  'tudo metade': 750,
#  'tudo metade preço': 751,
#  'tudo nogento': 752,
#  'tudo nogento ainda': 753,
#  'tv': 754,
#  'tv pedir': 755,
#  'tv pedir ajuda': 756,
#  'tá': 757,
#  'tá dormindo': 758,
#  'umm': 759,
#  'umm anti': 760,
#  'umm anti virus': 761,
#  'vacina': 762,
#  'vacina coronavirus': 763,
#  'vacina coronavirus bolsonaro': 764,
#  'vai': 765,
#  'vai compra': 766,
#  'vai compra porque': 767,
#  'vai td': 768,
#  'vai td tv': 769,
#  'vai ter': 770,
#  'vai ter pagodinho': 771,
#  'vai ver': 772,
#  'vai ver tag': 773,
#  'valores': 774,
#  'valores fundamentais': 775,
#  'valores fundamentais respeito': 776,
#  'vamo': 777,
#  'vamo chama': 778,
#  'vamo chama cara': 779,
#  'vamos': 780,
#  'vamos vencer': 781,
#  'vamos vencer discurso': 782,
#  'vcs': 783,
#  'vcs foda': 784,
#  'vejo': 785,
#  'vejo hora': 786,
#  'vejo hora lula': 787,
#  'vencer': 788,
#  'vencer discurso': 789,
#  'vencer discurso ódio': 790,
#  'ver': 791,
#  'ver pobre': 792,
#  'ver pobre sendo': 793,
#  'ver tag': 794,
#  'ver tag 12h': 795,
#  'vermes': 796,
#  'vermes raiva': 797,
#  'vermes raiva ódio': 798,
#  'vida': 799,
#  'vida coisas': 800,
#  'vida coisas nunca': 801,
#  'virus': 802,
#  'virus coreação': 803,
#  'virus coreação rsrsrsrsrssrsrrsrsrsrs': 804,
#  'vivam': 805,
#  'vivam bolsa': 806,
#  'vivam bolsa caralho': 807,
#  'volta': 808,
#  'volta pra': 809,
#  'volta pra pqp': 810,
#  'volta pra terra': 811,
#  'xbox': 812,
#  'xbox seguidores': 813,
#  'xboxbr': 814,
#  'xboxbr reafirmando': 815,
#  'xboxbr reafirmando compromisso': 816,
#  'ódio': 817,
#  'ódio dessa': 818,
#  'ódio dessa gente': 819,
#  'ódio liberdade': 820,
#  'ódio liberdade expressão': 821,
#  'ódio menos': 822,
#  'ódio menos desprezo': 823,
#  'ódio preconceituosos': 824,
#  'ódio preconceituosos passarão': 825,
#  'ódio sim': 826,
#  'ódio sim paz': 827,
#  'ódio ódio': 828}

# %%
# Por fim, realizamos as predições no conjunto de *teste*
y_pred = modelo.predict(X_test)

# %%
# Verificamos as predições em uma tabela
pd.DataFrame({'mensagem': X_test, 'classificacao': y_pred})
# Out:
#                                              mensagem classificacao
# 2   Não maltrataram ela? Não a estruparam com viol...          hate
# 22                          Bom dia negros fedidos :D       regular
# 14  O Nordeste elege o PT e fode o país, quando qu...          hate
# 17  Homem é foda né, a mina pode ter peitão, bundã...       regular
# 5   o curioso caso do sei do que eu to falando mas...       regular
# 11  Discurso de ódio mata sim. Não disfarce isso c...          hate

# %%
# Verificamos o desempenho do modelo
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         hate       0.67      0.67      0.67         3
#      regular       0.67      0.67      0.67         3
#
#     accuracy                           0.67         6
#    macro avg       0.67      0.67      0.67         6
# weighted avg       0.67      0.67      0.67         6
